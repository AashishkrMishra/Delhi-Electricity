# %%
import pandas as pd
df=pd.read_csv("FINAL_DATASET.csv")
df.head()
# Out:
#          Subdistrict  consumption_per_day  Month  Day
# 0       Chanakyapuri             0.155784      1    2
# 1    Connaught Place             0.071641      1    2
# 2  Parliament Street             0.132973      1    2
# 3             Narela             2.055507      1    2
# 4   Delhi Cantonment             0.726205      1    2

# %%
dummies=pd.get_dummies(df['Subdistrict'])
dummies
# Out:
#       Chanakyapuri  Civil Lines  Connaught Place  Daryaganj  Defence Colony  \
# 0             True        False            False      False           False
# 1            False        False             True      False           False
# 2            False        False            False      False           False
# 3            False        False            False      False           False
# 4            False        False            False      False           False
# ...            ...          ...              ...        ...             ...
# 9688         False        False            False      False           False
# 9689         False        False            False      False           False
# 9690         False        False            False      False           False
# 9691         False        False            False      False           False
# 9692         False        False            False      False           False
#
# ...

# %%
merged=pd.concat([df,dummies], axis='columns')
merged
# Out:
#             Subdistrict  consumption_per_day  Month  Day  Chanakyapuri  \
# 0          Chanakyapuri             0.155784      1    2          True
# 1       Connaught Place             0.071641      1    2         False
# 2     Parliament Street             0.132973      1    2         False
# 3                Narela             2.055507      1    2         False
# 4      Delhi Cantonment             0.726205      1    2         False
# ...                 ...                  ...    ...  ...           ...
# 9688          Seemapuri             2.154418     12   31         False
# 9689       Gandhi Nagar             1.577532     12   31         False
# 9690          Paharganj             0.696758     12   31         False
# 9691           Shahdara             1.288591     12   31         False
# 9692     Rajouri Garden             1.921855     12   31         False
#
#       Civil Lines  Connaught Place  Daryaganj  Defence Colony  \
# ...

# %%
merged = merged.drop('Subdistrict', axis='columns')
merged
# Out:
#       consumption_per_day  Month  Day  Chanakyapuri  Civil Lines  \
# 0                0.155784      1    2          True        False
# 1                0.071641      1    2         False        False
# 2                0.132973      1    2         False        False
# 3                2.055507      1    2         False        False
# 4                0.726205      1    2         False        False
# ...                   ...    ...  ...           ...          ...
# 9688             2.154418     12   31         False        False
# 9689             1.577532     12   31         False        False
# 9690             0.696758     12   31         False        False
# 9691             1.288591     12   31         False        False
# 9692             1.921855     12   31         False        False
#
#       Connaught Place  Daryaganj  Defence Colony  Delhi Cantonment  \
# 0               False      False           False             False
# ...

# %%
month_dummies = pd.get_dummies(df['Month'], prefix='Month')
month_dummies
# Out:
#       Month_1  Month_2  Month_3  Month_4  Month_5  Month_6  Month_7  Month_8  \
# 0        True    False    False    False    False    False    False    False
# 1        True    False    False    False    False    False    False    False
# 2        True    False    False    False    False    False    False    False
# 3        True    False    False    False    False    False    False    False
# 4        True    False    False    False    False    False    False    False
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 9688    False    False    False    False    False    False    False    False
# 9689    False    False    False    False    False    False    False    False
# 9690    False    False    False    False    False    False    False    False
# 9691    False    False    False    False    False    False    False    False
# 9692    False    False    False    False    False    False    False    False
#
#       Month_9  Month_10  Month_11  Month_12
# ...

# %%
Day_dummies = pd.get_dummies(df['Day'], prefix='Day')
Day_dummies
# Out:
#       Day_1  Day_2  Day_3  Day_4  Day_5  Day_6  Day_7  Day_8  Day_9  Day_10  \
# 0     False   True  False  False  False  False  False  False  False   False
# 1     False   True  False  False  False  False  False  False  False   False
# 2     False   True  False  False  False  False  False  False  False   False
# 3     False   True  False  False  False  False  False  False  False   False
# 4     False   True  False  False  False  False  False  False  False   False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
# 9688  False  False  False  False  False  False  False  False  False   False
# 9689  False  False  False  False  False  False  False  False  False   False
# 9690  False  False  False  False  False  False  False  False  False   False
# 9691  False  False  False  False  False  False  False  False  False   False
# 9692  False  False  False  False  False  False  False  False  False   False
#
# ...

# %%
final=pd.concat([merged, month_dummies, Day_dummies], axis=1)
final
# Out:
#       consumption_per_day  Month  Day  Chanakyapuri  Civil Lines  \
# 0                0.155784      1    2          True        False
# 1                0.071641      1    2         False        False
# 2                0.132973      1    2         False        False
# 3                2.055507      1    2         False        False
# 4                0.726205      1    2         False        False
# ...                   ...    ...  ...           ...          ...
# 9688             2.154418     12   31         False        False
# 9689             1.577532     12   31         False        False
# 9690             0.696758     12   31         False        False
# 9691             1.288591     12   31         False        False
# 9692             1.921855     12   31         False        False
#
#       Connaught Place  Daryaganj  Defence Colony  Delhi Cantonment  \
# 0               False      False           False             False
# ...

# %%
final = final.drop('Month', axis='columns')
final
# Out:
#       consumption_per_day  Day  Chanakyapuri  Civil Lines  Connaught Place  \
# 0                0.155784    2          True        False            False
# 1                0.071641    2         False        False             True
# 2                0.132973    2         False        False            False
# 3                2.055507    2         False        False            False
# 4                0.726205    2         False        False            False
# ...                   ...  ...           ...          ...              ...
# 9688             2.154418   31         False        False            False
# 9689             1.577532   31         False        False            False
# 9690             0.696758   31         False        False            False
# 9691             1.288591   31         False        False            False
# 9692             1.921855   31         False        False            False
#
# ...

# %%
final = final.drop('Day', axis='columns')
final
# Out:
#       consumption_per_day  Chanakyapuri  Civil Lines  Connaught Place  \
# 0                0.155784          True        False            False
# 1                0.071641         False        False             True
# 2                0.132973         False        False            False
# 3                2.055507         False        False            False
# 4                0.726205         False        False            False
# ...                   ...           ...          ...              ...
# 9688             2.154418         False        False            False
# 9689             1.577532         False        False            False
# 9690             0.696758         False        False            False
# 9691             1.288591         False        False            False
# 9692             1.921855         False        False            False
#
#       Daryaganj  Defence Colony  Delhi Cantonment  Gandhi Nagar  Hauz Khas  \
# ...

# %%
#from sklearn.linear_model import LinearRegression
#model=LinearRegression()

# %%
#X=final.drop('consumption_per_day', axis='columns')
#X

# %%
#Y=final.consumption_per_day
#Y

# %%
#model.fit(X,Y)

# %%
#model.score(X,Y)

# %%
from sklearn.model_selection import train_test_split
X=final.drop('consumption_per_day', axis='columns')
Y=final.consumption_per_day
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
#model = LinearRegression()
#model.fit(X_train, Y_train)

# %%
#y_pred = model.predict(X_test)
#y_pred

# %%
#model.score(X_test,Y_test)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
model = SVR(kernel='rbf', C=100, epsilon=0.1)

# %%
model.fit(X_train_scaled, Y_train)
# Out:
# SVR(C=100)

# %%
y_pred = model.predict(X_test_scaled)
y_pred
# Out:
# array([1.44626955, 0.57788524, 0.60793977, ..., 2.28718566, 0.87437707,
#        0.79657892])

# %%
model.score(X_test_scaled,Y_test)
# Out:
# 0.9155072027270265

# %%
file=X_test

# %%
# Save DataFrame to CSV
file.to_csv('x_test.csv', index=False)

# %%
model.predict([[True, False, True, True, False, True , False, True, True, False, True, False, True, True, False, True, False, True, True, False, True, False, True, True, False, True, False, True, True, False, True, False, True, True, False, True, False, True, True, False, True, False, True, True, False, True, False, True, True, False, True, False, True, True, False, True, False, True, True, False, True, False, True, True, False, True, False, True, False, True]])
# Out:
# array([1.28300157])

# %%
def user_input():
     input_day=input("please enter day")
     input_district=input("please enter district")
     input_month=input("please enter month")

# %%
def input():
 sub_districts =["Chanakyapuri","Civil Lines", "Connaught Place", "Daryaganj", "Defence Colony", "Delhi Cantonment", "Gandhi Nagar", 
"Hauz Khas", "Kalkaji", "Karol Bagh", "Kotwali", "Model Town", "Najafgarh", "Narela", "Paharganj", "Parliament Street", "Patel Nagar",
"Preet Vihar", "Punjabi Bagh", "Rajouri Garden", "Sadar Bazaar", "Saraswati Vihar", "Seelampur", "Seemapuri", "Shahdara", "Vasant Vihar",
"Vivek Vihar"]
 month= ["Month_1", "Month_2", "Month_3", "Month_4", "Month_5", "Month_6", "Month_7", "Month_8",	"Month_9", "Month_10", "Month_11", 
        "Month_12"]
 day=["Day_1", "Day_2", "Day_3", "Day_4", "Day_5", "Day_6", "Day_7", "Day_8", "Day_9", "Day_10", "Day_11", "Day_12", "Day_13", "Day_14", 
      "Day_15", "Day_16", "Day_17", "Day_18", "Day_19", "Day_20", "Day_21", "Day_22", "Day_23", "Day_24", "Day_25", "Day_26", "Day_27"
     , "Day_28", "Day_29", "Day_30", "Day_31"]
 inputDistrict=[]
 inputMonth=[]
 inputDay=[]
 for district in sub_districts:
    if district == input_district:
        inputDistrict.append(True)
    else:
        inputDistrict.append(False)
 
 for days in day:
    if days == input_day:
        inputDay.append(True)
    else:
        inputDay.append(False)  

 for months in month:
    if months == input_month:
        inputMonth.append(True)
    else:
        inputMonth.append(False)

 merged_input=inputDistrict+inputMonth+inputDay
 return merged_input

# %%
inputPredict=input()
model.predict([inputPredict])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 inputPredict=input()
#       2 model.predict([inputPredict])
#
# TypeError: input() missing 3 required positional arguments: 'input_district', 'input_month', and 'input_day'

# %%
from joblib import dump

# %%
dump(model,'MLmodel.joblib')

# %%
day_data = final[final[selected_day] == True]
district_columns = [col for col in sub_districts if col in final.columns]
selected_day='Day_30'
consumption_dict = {}
for district in district_columns:
    total_consumption = day_data.loc[day_data[district] == True, 'consumption_per_day'].sum()
    consumption_dict[district] = total_consumption
consumption_series = pd.Series(consumption_dict)
plt.figure(figsize=(12, 8))
plt.bar(consumption_series.index, consumption_series.values, color='skyblue')
plt.xlabel('District')
plt.ylabel('Consumption')
plt.title(f'Consumption by District on {selected_day}')
plt.xticks(rotation=90)  
plt.tight_layout()  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 day_data = final[final[selected_day] == True]
#       2 district_columns = [col for col in sub_districts if col in final.columns]
#       3 selected_day='Day_30'
#
# NameError: name 'selected_day' is not defined

# %%
selected_day = 'Day_30'
if selected_day not in final.columns:
    raise ValueError(f"Column {selected_day} does not exist in the dataset.")
day_data = final[final[selected_day] == True]
district_columns = [col for col in sub_districts if col in final.columns]
consumption_dict = {}

for district in district_columns:
    total_consumption = day_data.loc[day_data[district] == True, 'consumption_per_day'].sum()
    consumption_dict[district] = total_consumption

consumption_series = pd.Series(consumption_dict)


plt.figure(figsize=(12, 8))
plt.pie(consumption_series, labels=consumption_series.index, autopct='%1.1f%%', startangle=140)
plt.title(f'Consumption by District on {selected_day}')
plt.axis('equal')  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 5
#       3     raise ValueError(f"Column {selected_day} does not exist in the dataset.")
#       4 day_data = final[final[selected_day] == True]
# ----> 5 district_columns = [col for col in sub_districts if col in final.columns]
#       6 consumption_dict = {}
#       8 for district in district_columns:
#
# NameError: name 'sub_districts' is not defined
